# %%
import pandas as pd

# %%
df = pd.read_csv("cities.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Country             City    Lat     Lng  Temp F        Date  \
# 0           0      RU  Severo-Kuril'sk  50.68  156.12   34.39  1587240637
# 1           1      RU           Dikson  73.51   80.55   35.24  1587240493
# 2           2      IT             Laas  46.62   10.70   55.40  1587240649
# 3           3      TO            Vaini -21.20 -175.20   77.00  1587240488
# 4           4      NZ            Bluff -46.60  168.33   43.00  1587240576
#
#    Humidity  Max Temp  Wind Speed  Cloudiness
# 0        88     34.39       10.07           9
# 1        89     35.24       19.10         100
# 2        58     55.40        2.24          40
# 3        83     77.00       10.29          40
# 4        91     43.00        5.01         100

# %%
df_short = df[['Country','City','Lat','Lng','Temp F','Date','Humidity','Max Temp','Wind Speed','Cloudiness']]

# %%
df_short.head()
# Out:
#   Country             City    Lat     Lng  Temp F        Date  Humidity  \
# 0      RU  Severo-Kuril'sk  50.68  156.12   34.39  1587240637        88
# 1      RU           Dikson  73.51   80.55   35.24  1587240493        89
# 2      IT             Laas  46.62   10.70   55.40  1587240649        58
# 3      TO            Vaini -21.20 -175.20   77.00  1587240488        83
# 4      NZ            Bluff -46.60  168.33   43.00  1587240576        91
#
#    Max Temp  Wind Speed  Cloudiness
# 0     34.39       10.07           9
# 1     35.24       19.10         100
# 2     55.40        2.24          40
# 3     77.00       10.29          40
# 4     43.00        5.01         100

# %%
df_short.to_html("cities.html")
